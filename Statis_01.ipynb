# %%
import pandas as pd

# %%
data = pd.read_csv('flights.csv')
data.head()
# Out:
#    Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0           0  2013      1    1     517.0             515        2.0
# 1           1  2013      1    1     533.0             529        4.0
# 2           2  2013      1    1     542.0             540        2.0
# 3           3  2013      1    1     544.0             545       -1.0
# 4           4  2013      1    1     554.0             600       -6.0
#
#    arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 0     830.0             819       11.0  ...   1545   N14228    EWR  IAH
# 1     850.0             830       20.0  ...   1714   N24211    LGA  IAH
# 2     923.0             850       33.0  ...   1141   N619AA    JFK  MIA
# 3    1004.0            1022      -18.0  ...    725   N804JB    JFK  BQN
# 4     812.0             837      -25.0  ...    461   N668DN    LGA  ATL
#
#   air_time  distance  hour  minute            time_hour  \
# 0    227.0      1400     5      15  2013-01-01 05:00:00
# 1    227.0      1416     5      29  2013-01-01 05:00:00
# 2    160.0      1089     5      40  2013-01-01 05:00:00
# 3    183.0      1576     5      45  2013-01-01 05:00:00
# 4    116.0       762     6       0  2013-01-01 06:00:00
#
#                      name
# 0   United Air Lines Inc.
# 1   United Air Lines Inc.
# 2  American Airlines Inc.
# 3         JetBlue Airways
# 4    Delta Air Lines Inc.
#
# [5 rows x 21 columns]

# %%
data.dropna()
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0                0  2013      1    1     517.0             515        2.0
# 1                1  2013      1    1     533.0             529        4.0
# 2                2  2013      1    1     542.0             540        2.0
# 3                3  2013      1    1     544.0             545       -1.0
# 4                4  2013      1    1     554.0             600       -6.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 336765      336765  2013      9   30    2240.0            2245       -5.0
# 336766      336766  2013      9   30    2240.0            2250      -10.0
# 336767      336767  2013      9   30    2241.0            2246       -5.0
# 336768      336768  2013      9   30    2307.0            2255       12.0
# 336769      336769  2013      9   30    2349.0            2359      -10.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 0          830.0             819       11.0  ...   1545   N14228    EWR  IAH
# 1          850.0             830       20.0  ...   1714   N24211    LGA  IAH
# 2          923.0             850       33.0  ...   1141   N619AA    JFK  MIA
# 3         1004.0            1022      -18.0  ...    725   N804JB    JFK  BQN
# 4          812.0             837      -25.0  ...    461   N668DN    LGA  ATL
# ...          ...             ...        ...  ...    ...      ...    ...  ...
# 336765    2334.0            2351      -17.0  ...   1816   N354JB    JFK  SYR
# 336766    2347.0               7      -20.0  ...   2002   N281JB    JFK  BUF
# 336767    2345.0               1      -16.0  ...    486   N346JB    JFK  ROC
# 336768    2359.0            2358        1.0  ...    718   N565JB    JFK  BOS
# 336769     325.0             350      -25.0  ...    745   N516JB    JFK  PSE
#
#        air_time  distance  hour  minute            time_hour  \
# 0         227.0      1400     5      15  2013-01-01 05:00:00
# 1         227.0      1416     5      29  2013-01-01 05:00:00
# 2         160.0      1089     5      40  2013-01-01 05:00:00
# 3         183.0      1576     5      45  2013-01-01 05:00:00
# 4         116.0       762     6       0  2013-01-01 06:00:00
# ...         ...       ...   ...     ...                  ...
# 336765     41.0       209    22      45  2013-09-30 22:00:00
# 336766     52.0       301    22      50  2013-09-30 22:00:00
# 336767     47.0       264    22      46  2013-09-30 22:00:00
# 336768     33.0       187    22      55  2013-09-30 22:00:00
# 336769    196.0      1617    23      59  2013-09-30 23:00:00
#
#                           name
# 0        United Air Lines Inc.
# 1        United Air Lines Inc.
# 2       American Airlines Inc.
# 3              JetBlue Airways
# 4         Delta Air Lines Inc.
# ...                        ...
# 336765         JetBlue Airways
# 336766         JetBlue Airways
# 336767         JetBlue Airways
# 336768         JetBlue Airways
# 336769         JetBlue Airways
#
# [327346 rows x 21 columns]

# %%
data['arr_delay'].dropna().mean()
# Out:
# 6.89537675731489

# %%
from scipy import stats
stats.trim_mean(data['arr_delay'], 0.1)
# Out:
# 0.9612355338465307

# %%
import seaborn as sns
import numpy as np

# %%
d = np.random.poisson(lam= 7, size=1000)
print(d)
# Out:
# [ 6 10  7  4  4 10  4  6  6 13  4  9  6 12  9  9  5  8  4  7  3  6  3  6
#   9  4  4  9  2  6  6  7  8  8  5  3  7  4  3  8  5  5  5  7  8  6  5  9
#   6  3  6 11  4  4  9 14  9  2 12  7  6  6  6 10  6  5  9  7  4  4  8 10
#   5  3 12  5  8  6  8  7  4  3  7  6 12  8  5  5 11  7  7  7  7  6  4  5
#   9  9 13  9  9  6  5  6  8  6  5  8  5  6  8  7  7  8 10  6 11 13  8  8
#   7  8  9  8  7  4  7  7  5  4  4  6  2  7  8  6  4  8  7 10  9  7  9  5
#  14  6 11  8  2  5  7  9  3  4  8  6  7  8  8  8  7  9  3 14  7  3  7  6
#   8  6  5  8 10  4  9  4 16  7  7  7  6  3  6  8 10  7  7  4 11  8  2  6
#   7  7  5 10  3  6  7  5  8  2  5  4  9  3  5  6 10  9  7  5 10  9  7  5
#  11 11  5  9  5  7  5  5  3  4  2 11  7  7  8  8  4 11 15  8 11  5  7  9
#   9  7  9  7  4 10  6  7  6  7 12  8  9  9  8  8 11 10  9  8 11  5  7  6
#   6  5  4  6 10  6  7  6  6  9  5  6  6 10 10  6  5  2  7  5  6  3  7  7
#   7  3  5  6  7  7 13  8 10  6  5  9  9  7  7 13  9  4 11  6 10 13  7 12
#  12 13  3 11  9  3  7 14  6  4  7  6  8  9  8  7  2  8  5  6  7 10  5  7
#   2  8 12  6  3 11  7  6  7  5 10  5  4  3  4 11  7  9 10  6 10  4 10  5
#  10  7  7  7  8  9  4  6  6  7  8 10  6 10 13  7  1 11  6  4 12 10  6  5
#   8 10  8  8  5  8  9 15 10  6  7  6  4 10  6 12  7 11 14  7  9  2  8  8
#  12  4 11  8  6  7  4 12  8  1  3  6  5  4  8  8  5  7  9  3  3  4  8  7
#   4 13 11  8  7 11  7  9  3 11  9  3  7  9  4 11  8  8  9  4  8  5  4  7
#   9  7  1  7  6 11  7  7  5  5  7  1 13  9 11  9  3  7  5  6  6  5  5  8
#   3  7  9  4  6  6  6  6  6  8  5  3  5  7 14  6  6  5  7  3  3 12  5 10
#   7  6  9  5  9  4 11  9  7  3  9  6  5  8  2  6  6  6  9  9 11  6  5  7
#   5  5  7  4  6  7  6  9  6  9 10  9 10 10  7 10 10 10  3  5  9 16  6  8
#   4  3  9  7 11  7 13  9 14  8  4  5  5  8  9  7  3  3 12  7  8  8 10 10
#   7  9  5  7  4  9  7  4  5 10  8  1  9  4 13 11 10 10  4  8  8  7  7  6
#   5 12  5  3 12 13  8 12 10  3  3 10  9  6  5  8  4  8  8  5 12  4 14  8
#   4  8  5 11  7  4  4  7 11  8  2 10  8  5  5  5  5  4  6  7  6  4  5  5
#   2 10  9  5  3  8  8  6  9  5  7  7  6  6  5  4  5 10  7 12  6  4 10  5
#   3  7  6 12  8  8  7 10  9  8  9  7  4  7  9  5  4  8  7  5  7 12  6  8
#   5  8  7  7  6  5  4  9  6  5  4 15 10  5  9  4  7  4  5  9 10  5  9  6
#   9  9  8  5  5  5  7  5  3  9  6  7  4  5 10  6  7 10  6 10  6 14 12  6
#   3 11 10  8 11  7  8  5  5  3 11  6  5 12 11  6  7 10  6  7  5  8  9 11
#   3  5  6  8  6  9  8  6  9  5  9  6  8  4  7 11  6 10  6  1  6  7  8  6
#   7 10  5  3  6  8  7  9  8  3  6  6  8  7  4 10  7 10 11  7  3  5 12  3
#   7  7  3 10  6  4  2 11  8  8  8  9  9 10  5  3 11 12  6 10  8  8  5  8
#   7  8  5 11  8  7  8  8  8  9  6  5  5  9  8  6  6  7  5  7  4  5 12 11
#   7 10  4  7  8  5  5  7  5  5  5  9  8  8  6  6  8  7 13  7  7  7  8  4
#   5  3  8  9  9 12 10  8  6 10  4 12 12  4 10 14  5  5  5  4  9  7  5  5
#  12  7  7 10 14 10 11  7  9  7  5  9  9  8  5  8  4  6  4  9  7 11  6  8
#   8  4  8  9  3  7 11  5  7 12  9  6  5  7  5 10 11  8  9  7 13  7  1  6
#   3  4  7  6  9  2 13  3  8  5  2  8  7  7  9  6 11  4  8 10  6  3 12  8
#   6  7 12 10 10  6  5  8  8 10  5  5  6  8  7  7]

# %%
sns.distplot(d, kde= False)
# Out:
# <AxesSubplot:>

# %%
d = np.random.exponential(scale=2, size=1000)

# %%
sns.distplot(d, bins=150)
# Out:
# C:\Users\Mahdi Poudeh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
